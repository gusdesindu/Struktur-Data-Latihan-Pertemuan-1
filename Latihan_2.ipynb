# %% [markdown]
# <a href="https://colab.research.google.com/github/gusdesindu/Struktur-Data-Latihan-Pertemuan-1/blob/main/Latihan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# definisikan list kosong untuk menyimpan data

# %%
list = []

# %% [markdown]
# input 10 angka

# %%
for i in range(10):
  angka = int(input("Masukkan angka: "))
  list.append(angka)
# Out:
# Masukkan angka: 1
# Masukkan angka: 5
# Masukkan angka: 9
# Masukkan angka: 2
# Masukkan angka: 6
# Masukkan angka: 10
# Masukkan angka: 3
# Masukkan angka: 7
# Masukkan angka: 8
# Masukkan angka: 4

# %% [markdown]
# tampilkan nilai maksimum, minimum, dan rata-rata

# %%
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [1, 5, 9, 2, 6, 10, 3, 7, 8, 4]
# Nilai maksimum: 10
# Nilai minimum: 1
# Rata-rata: 5.5

# %% [markdown]
# buat grafik batang menggunakan matplotlib

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
